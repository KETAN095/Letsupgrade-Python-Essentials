# %% [markdown]
# # Qusetion 1

# %%
num = input("enter value whether to check it is safe to land or not !")
num1 = int(num)

if num1<=1000:
    print("SAFE TO LAND")
elif num1<=4500:
    print("BRING DOWN TO 1000")
else:
    print(" TURN AROUND")
# Out:
# enter value whether to check it is safe to land or not !3500
# BRING DOWN TO 1000

# %%
num = input("enter value whether to check it is safe to land or not !")
num1 = int(num)

if num1<=1000:
    print("SAFE TO LAND")
elif num1<=4500:
    print("BRING DOWN TO 1000")
else:
    print(" TURN AROUND")
# Out:
# enter value whether to check it is safe to land or not !5500
#  TURN AROUND

# %%
num = input("enter value whether to check it is safe to land or not !")
num1 = int(num)

if num1<=1000:
    print("SAFE TO LAND")
elif num1<=4500:
    print("BRING DOWN TO 1000")
else:
    print(" TURN AROUND")
# Out:
# enter value whether to check it is safe to land or not !999
# SAFE TO LAND

# %% [markdown]
# # QUESTION 2

# %%
p= 1 
q = 201
j= int(p)
k = int(q)
for i in range(j,k):
    if i>1 and i%2 == 0:
        print(" ")
    else:
        print("prime number is  = ",i)
# Out:
# prime number is  =  1
#
# prime number is  =  3
#
# prime number is  =  5
#
# prime number is  =  7
#
# prime number is  =  9
#
# prime number is  =  11
#
# prime number is  =  13
#
# prime number is  =  15
#
# prime number is  =  17
#
# prime number is  =  19
#
# prime number is  =  21
#
# prime number is  =  23
#
# prime number is  =  25
#
# prime number is  =  27
#
# prime number is  =  29
#
# prime number is  =  31
#
# prime number is  =  33
#
# prime number is  =  35
#
# prime number is  =  37
#
# prime number is  =  39
#
# prime number is  =  41
#
# prime number is  =  43
#
# prime number is  =  45
#
# prime number is  =  47
#
# prime number is  =  49
#
# prime number is  =  51
#
# prime number is  =  53
#
# prime number is  =  55
#
# prime number is  =  57
#
# prime number is  =  59
#
# prime number is  =  61
#
# prime number is  =  63
#
# prime number is  =  65
#
# prime number is  =  67
#
# prime number is  =  69
#
# prime number is  =  71
#
# prime number is  =  73
#
# ...
